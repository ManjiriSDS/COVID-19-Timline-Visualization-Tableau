# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# ### Importing necessary libraries

# %% [markdown]
# #### The following code is written in Python 3.x. libraries provide pre-written functionally to perform necessary tasks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the Data
data = pd.read_csv('C:/Users/Public/Downloads/owid-covid-data.csv', header = 0, index_col = 0)

# %%
#Printing no. of rows and no. of columns of data
data.shape
# Out:
# (81905, 58)

# %%
#Printing top 5 rows
data.head()
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          1.0        1.0
# AFG           Asia  Afghanistan  2020-02-25          1.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          1.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          1.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          1.0        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
#
#           total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81905 entries, AFG to ZWE
# Data columns (total 58 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   continent                              77929 non-null  object
#  1   location                               81905 non-null  object
#  2   date                                   81905 non-null  object
#  3   total_cases                            80087 non-null  float64
#  4   new_cases                              80085 non-null  float64
#  5   new_cases_smoothed                     79084 non-null  float64
#  6   total_deaths                           70548 non-null  float64
#  7   new_deaths                             70706 non-null  float64
#  8   new_deaths_smoothed                    79084 non-null  float64
#  9   total_cases_per_million                79653 non-null  float64
# ...

# %% [markdown]
# ### Handling Missing Values

# %%
#Check for missing values in any columns
data.isnull().sum()
# Out:
# continent                                 3976
# location                                     0
# date                                         0
# total_cases                               1818
# new_cases                                 1820
# new_cases_smoothed                        2821
# total_deaths                             11357
# new_deaths                               11199
# new_deaths_smoothed                       2821
# total_cases_per_million                   2252
# new_cases_per_million                     2254
# new_cases_smoothed_per_million            3250
# total_deaths_per_million                 11778
# new_deaths_per_million                   11620
# new_deaths_smoothed_per_million           3250
# reproduction_rate                        15875
# icu_patients                             73449
# icu_patients_per_million                 73449
# hosp_patients                            71778
# hosp_patients_per_million                71778
# ...

# %%
#Replacing null values with O
data.fillna(value = 0, inplace = True)

# %%
data.head()
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          1.0        1.0
# AFG           Asia  Afghanistan  2020-02-25          1.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          1.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          1.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          1.0        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      0.0           0.0         0.0                  0.0
# AFG                      0.0           0.0         0.0                  0.0
# AFG                      0.0           0.0         0.0                  0.0
# AFG                      0.0           0.0         0.0                  0.0
# AFG                      0.0           0.0         0.0                  0.0
#
#           total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
data.isnull().sum()
# Out:
# continent                                0
# location                                 0
# date                                     0
# total_cases                              0
# new_cases                                0
# new_cases_smoothed                       0
# total_deaths                             0
# new_deaths                               0
# new_deaths_smoothed                      0
# total_cases_per_million                  0
# new_cases_per_million                    0
# new_cases_smoothed_per_million           0
# total_deaths_per_million                 0
# new_deaths_per_million                   0
# new_deaths_smoothed_per_million          0
# reproduction_rate                        0
# icu_patients                             0
# icu_patients_per_million                 0
# hosp_patients                            0
# hosp_patients_per_million                0
# weekly_icu_admissions                    0
# weekly_icu_admissions_per_million        0
# ...

# %%
data.to_csv('C:/Users/Public/Downloads/cleaned-covid-data.csv', header = True, index = True)

# %% [markdown]
# ### Handling Duplicate Records

# %%
#Check for duplicate data
duplicate = data.duplicated()
print(duplicate.sum())
data[duplicate]
# Out:
# 0
# Empty DataFrame
# ...
